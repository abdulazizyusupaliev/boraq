# %% [markdown]
# #**Class 2**

# %% [markdown]
# **Task 1: Import and Load the Data**

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/SampleSuperstore.csv', encoding='ISO-8859-1')
df.head(10)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# ...

# %% [markdown]
# **Task 2: Inspect the Structure**

# %%
print("Shape:", df.shape) # (rows, columns)
# Out:
# Shape: (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# **The dataset contains 9,994 rows and 21 columns, providing a comprehensive view of the Superstore operations.**
# **Upon inspection, there are no missing values across any of the columns, indicating a very clean dataset.**
# **A surprising statistical find is the extreme variance in profitability;**
# **while the average profit is roughly $28.66 , the values range from a significant loss of -$6,599.98 to a maximum profit of $8,399.97, suggesting that certain transactions are highly volatile.**

# %% [markdown]
# **Task 3: Handle Missing Values**

# %%
print(df.isnull().sum())
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# **`After inspecting the dataset using df.isnull().sum(), it was found that there are no missing values in any of the 21 columns. Since the data is complete, no filling (median or mode) was required`**

# %% [markdown]
# **Task 4: Remove Duplicates**

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %% [markdown]
# **There's no dublicates**

# %% [markdown]
# **Task 5: Convert Data Types**

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
print(df.dtypes)
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df[['Order Date', 'Ship Date']].head()
# Out:
#   Order Date  Ship Date
# 0 2016-11-08 2016-11-11
# 1 2016-11-08 2016-11-11
# 2 2016-06-12 2016-06-16
# 3 2015-10-11 2015-10-18
# 4 2015-10-11 2015-10-18

# %% [markdown]
# **Task 6: Create Derived Features**

# %%
total_spending = df.groupby('Customer ID')['Sales'].sum().reset_index()
total_spending.columns = ['Customer ID', 'total_spending']

# %%
order_freq = df.groupby('Customer ID')['Order ID'].nunique().reset_index()
order_freq.columns = ['Customer ID', 'order_frequency']

# %%
avg_order = df.groupby('Customer ID')['Sales'].mean().reset_index()
avg_order.columns = ['Customer ID', 'avg_order_value']

# %%
customer_summary = total_spending.merge(order_freq, on='Customer ID') \
                                 .merge(avg_order, on='Customer ID')
customer_summary.head(10)
# Out:
#   Customer ID  total_spending  order_frequency  avg_order_value
# 0    AA-10315        5563.560                5       505.778182
# 1    AA-10375        1056.390                9        70.426000
# 2    AA-10480        1790.512                4       149.209333
# 3    AA-10645        5086.935                6       282.607500
# 4    AB-10015         886.156                3       147.692667
# 5    AB-10060        7755.620                8       430.867778
# 6    AB-10105       14473.571               10       723.678550
# 7    AB-10150         966.710                5        80.559167
# 8    AB-10165        1113.838                8        79.559857
# 9    AB-10255         914.532                9        65.323714

# %%
df.to_csv('superstore_cleaned.csv', index=False)
customer_summary.to_csv('customer_summary.csv', index=False)

# %% [markdown]
# #**Class 3**

# %% [markdown]
# **Task 1: Distribution Plots**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('superstore_cleaned.csv')
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Sales'], bins=50, color='steelblue', edgecolor='black')
plt.title('Distribution of Sales')
plt.xlabel('Sales ($)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **The Sales distribution is highly right-skewed. As seen in the histogram, the vast majority of transactions (over 8,000) are concentrated in the $0 to $1,000 range. This indicates that the business relies heavily on high-volume, low-value transactions. The "long tail" extending towards $20,000 shows that while expensive sales occur, they are rare exceptions rather than the norm.**

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Profit'], color='lightcoral')
plt.title('Boxplot of Profit')
plt.xlabel('Profit ($)')
plt.show()

# %% [markdown]
# In the Profit boxplot, the quartiles (the central box) are extremely compressed around the zero mark. This suggests that for 50% of the data, the profit or loss per transaction is very small. However, there are numerous visible outliers on both ends of the spectrum:
# Negative Outliers: Some transactions resulted in significant losses, reaching as low as -$6,000.
#
# Positive Outliers: On the other hand, certain "home run" sales generated profits as high as +$8,000

# %% [markdown]
# **Task 2: Category-Wise Trends**

# %%
cat_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(8, 5))
cat_sales.plot(kind='bar', color=['#2196F3', '#4CAF50', '#FF9800'])
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(8, 5))
region_sales.plot(kind='bar', color='steelblue')
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# While Technology is the leader, the gap between it, Furniture, and Office Supplies is relatively small. All three categories are performing well, indicating a diversified business model rather than reliance on just one type of product.
#
# There is a more noticeable drop-off in regional performance compared to categories. The South region generates significantly less revenue (under $400,000) compared to the West (over $700,000). This suggests that the business has a much stronger market presence on the coasts than in the Southern or Central United States.

# %% [markdown]
# **Task 3: Outlier Identification**

# %%
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)
IQR = Q3 - Q1
print(f"Q1: {Q1:.2f}, Q3: {Q3:.2f}, IQR: {IQR:.2f}")
# Out:
# Q1: 1.73, Q3: 29.36, IQR: 27.64

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print(f"Lower bound: {lower_bound:.2f}, Upper bound: {upper_bound:.2f}")
# Out:
# Lower bound: -39.72, Upper bound: 70.82

# %%
outliers = df[(df['Profit'] < lower_bound) | (df['Profit'] > upper_bound)]

print(f"Number of outliers: {len(outliers)} out of {len(df)} rows ({len(outliers)/len(df)*100:.2f}%)")
# Out:
# Number of outliers: 1881 out of 9994 rows (18.82%)

# %% [markdown]
# **I identified 1,881 outliers, which account for 18.82% of the total dataset. Based on the previous Profit boxplot, these outliers consist of both high-profit and high-loss items. While there are extreme losses reaching below -$6,000, there is a slightly more visible concentration of high-profit outliers extending up to approximately +$8,000. This indicates that while the business experiences significant volatility, it also benefits from occasional high-revenue transactions that deviate from the normal profit range.**

# %% [markdown]
# **Task 4: Correlation Heatmap**

# %%
numerical_cols = df[['Sales', 'Quantity', 'Discount', 'Profit']]
corr_matrix = numerical_cols.corr()
print(corr_matrix)
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f')
plt.title('Correlation Heatmap: Sales, Quantity, Discount, Profit')
plt.show()

# %% [markdown]
# **The strongest positive relationship is between Sales and Profit (0.48). This indicates that as sales revenue increases, profit tends to increase as well, which is a healthy sign for the business.
# There are negative correlations between Discount and Profit (-0.22) and Discount and Sales (-0.03).
# The negative correlation of -0.22 suggests that increasing discounts generally leads to lower profit margins. This implies that while discounts might be used to drive volume, they are currently cutting into the company's bottom line significantly.**

# %% [markdown]
# **Task 5: Time-Based Trend**

# %%
monthly_sales = df.resample('M', on='Order Date')['Sales'].sum()
# Out:
# /tmp/ipykernel_9431/1865667486.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df.resample('M', on='Order Date')['Sales'].sum()

# %%
plt.figure(figsize=(12, 6))
monthly_sales.plot(color='steelblue', linewidth=2)
plt.title('Monthly Total Sales Over Time')
plt.xlabel('Month')
plt.ylabel('Total Sales ($)')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# **The chart reveals a clear seasonal pattern where sales consistently increase towards the end of each year. Significant spikes occur every November and December, likely due to holiday shopping seasons. Conversely, there are notable dips every January and February, indicating a post-holiday slowdown in consumer spending. Overall, the business shows a positive year-over-year growth trend despite these seasonal fluctuations.**

# %% [markdown]
# **Task 6: Reflection Questions**

# %% [markdown]
# **1. Why is retail sales data often right-skewed?**
# In retail, the vast majority of transactions consist of everyday, low-to-medium value items, which creates a large "peak" on the left side of the histogram. However, there are occasionally very high-value sales—such as bulk corporate orders or luxury electronics—that create a "long tail" extending to the right. This imbalance between frequent small purchases and rare large ones results in a right-skewed distribution.
#
# **2. Should you remove outliers in Profit? What information might you lose?**
# No, profit outliers should not be removed because they represent the most significant financial events, such as "home run" sales or critical losses. By deleting them, you lose vital information about the business's volatility and its exposure to extreme financial risks or opportunities. These outliers often provide the most important insights into which specific strategies are working or failing.
#
# **3. If Discount and Profit have a negative correlation, does that mean the company should stop giving discounts?**
# Not necessarily, because correlation does not equal causation. While higher discounts are associated with lower profit margins per item, they may be a strategic necessity to increase total sales volume, clear out old inventory, or acquire new customers. The goal should be to find an "optimal" discount level rather than eliminating them entirely.
#
# **4. As a store manager, what action would you take based on the monthly sales trend?**
# Based on the clear seasonal spikes in November and December, I would increase inventory levels and hire seasonal staff in advance to handle the holiday peak. To address the notable dips in January and February, I would plan aggressive marketing campaigns or "New Year" clearance sales to stimulate demand during the post-holiday slowdown.

# %% [markdown]
# #**Class 4**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Task 1.1: Create DataFrame
df = pd.DataFrame({
    "name": ["Ali", "Zara", "Jasur"],
    "age": [22, 28, 31],
    "city": ["Tashkent", "Samarkand", "Bukhara"]
})

# Answer in code:
print(type(df["age"]))
print(type(df[["name", "age"]]))
print(df.index)

# Task 1.2: Add rows and reset index
new_rows = pd.DataFrame({
    "name": ["Malika", "Bekzod", "Laylo"],
    "age": [25, 30, 24],
    "city": ["Nukus", "Fergana", "Namangan"]
})

df = pd.concat([df, new_rows], ignore_index=True)
print(df)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex(start=0, stop=3, step=1)
#      name  age       city
# 0     Ali   22   Tashkent
# 1    Zara   28  Samarkand
# 2   Jasur   31    Bukhara
# 3  Malika   25      Nukus
# 4  Bekzod   30    Fergana
# 5   Laylo   24   Namangan

# %%
#Task 2.1
# Loading a public dataset (Tips dataset from seaborn's github)
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)
df.head() # Displays the first 5 rows to give a quick "snapshot" of what the data looks like.
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Task 2.2: Inspection Commands

df.shape # Shows the number of rows and columns (dimensionality) of the dataset.

df.info() # Shows the data types (integers, floats, objects) and how many non-null values are in each column.

df.describe() # Provides statistical summaries like mean, standard deviation, and quartiles for numeric columns.

df.isna().sum() # Counts the number of missing values in each column so I know if cleaning is needed.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#Task 3.1

# One column as Series
col_series = df["total_bill"]

# Two columns as DataFrame
cols_df = df[["total_bill", "tip"]]

# loc (label-based) - selecting the row at index label 0
row_loc = df.loc[0]

# iloc (position-based) - selecting the first row
row_iloc = df.iloc[0]

# %%
#Task 3.2

# Filter: Bills > 20 AND size is more than 2
filtered_df = df[(df["total_bill"] > 20) & (df["size"] > 2)]

# Filter: Day is Saturday OR Sunday
weekend_df = df[(df["day"] == "Sat") | (df["day"] == "Sun")]

# %%
#Task 3.3

# Pattern 1: Simple Mean
mean_tip = df.groupby("day")["tip"].mean()

# Pattern 2: Aggregate Multiple
agg_df = df.groupby("day").agg({
    "total_bill": "mean",
    "tip": "count"
})

print(type(mean_tip))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Task 3.4

# Create lookup table
lookup_data = pd.DataFrame({
    "day": ["Sat", "Sun", "Thur", "Fri"],
    "wait_time": ["High", "High", "Low", "Medium"]
})

# Left Merge
merged_df = pd.merge(df, lookup_data, on="day", how="left")

# %% [markdown]
# Answer:
# In a left merge, all rows from the left table (the main DataFrame) are kept, even if there is no match in the right table (the lookup). For rows without a match, the new columns from the lookup table will be filled with NaN (null) values

# %% [markdown]
# #**Class 5**

# %% [markdown]
# # Task 1.1
#
# Exploratory visualization is used by the analyst to find patterns, spot outliers, and understand the data's structure (it's "data for me"). Explanatory visualization is used to communicate a specific insight or story to an audience (it's "data for them"). In this assignment, I am producing exploratory visualizations because I am still investigating the dataset's distributions and relationships.

# %% [markdown]
# #Task 2.1

# %%
# Histogram
plt.figure()
plt.hist(df["total_bill"], bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Total Bill")
plt.show()

# Scatter
plt.figure()
plt.scatter(df["total_bill"], df["tip"], alpha=0.5)
plt.title("Bill vs Tip")
plt.show()

# %% [markdown]
# #Task 2.2

# %%
# Histogram with KDE
sns.histplot(df, x="total_bill", kde=True)
plt.show()

# Boxplot
sns.boxplot(df, x="day", y="total_bill")
plt.show()

# Scatterplot with Hue
sns.scatterplot(df, x="total_bill", y="tip", hue="time")
plt.show()

# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# #Task 2.3

# %%
# Generating sample data for squares
x = range(1, 11)
y = [i**2 for i in x]

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(x, y, marker='o', linestyle='-', color='purple')
ax.set_xlabel("Number")
ax.set_ylabel("Square Value")
ax.set_title("Squares of 1-10")

# Save to file
fig.savefig("out.png", dpi=150)
plt.show()

# %% [markdown]
# #Task 3.1: Audit (Using the Boxplot from 2.2)
# Labels/Units: Yes, axes are labeled "day" and "total_bill" (though units like "$" could be clearer).
#
# Y-axis Zero: Yes, the boxplot naturally shows the full range starting from near zero.
#
# Right Chart Type: Yes, a boxplot is perfect for comparing distributions across categories (days).
#
# Chartjunk: No, the Seaborn default is clean with no 3D effects or unnecessary shadows.
#
# Clear Message: Yes, it clearly shows that dinner bills tend to be higher on weekends.

# %% [markdown]
# #Task 3.4
# In the Tips dataset, the tip column often has a right tail (most tips are $2-$4, few are $10+).

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Linear Scale
ax1.hist(df["tip"], bins=20)
ax1.set_title("Linear Scale")

# Log Scale
ax2.hist(df["tip"], bins=20)
ax2.set_yscale("log")
ax2.set_title("Log Scale")

plt.show()
